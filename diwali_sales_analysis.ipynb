# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\SMITHA SEELAN\PycharmProjects\festive-sales-analysis-pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("data/dataset.csv", sep="\t")
df.head()      #first 5 data
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35  28.0             0.0
# 1  1000732     Kartik  P00110942      F     26-35  35.0             1.0
# 2  1001990      Bindu  P00118542      F     26-35  35.0             1.0
# 3  1001425     Sudevi  P00237842      M      0-17  16.0             0.0
# 4  1000588       Joni  P00057942      M     26-35  28.0             1.0
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto     1.0
# 1  Andhra Pradesh  Southern             Govt             Auto     3.0
# 2   Uttar Pradesh   Central       Automobile             Auto     3.0
# 3       Karnataka  Southern     Construction             Auto     2.0
# 4         Gujarat   Western  Food Processing             Auto     2.0
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape                #no. of rows and cols
# Out:
# (11252, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11252 entries, 0 to 11251
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11252 non-null  int64
#  1   Cust_name         11252 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  float64
#  6   Marital_Status    11251 non-null  float64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11250 non-null  float64
#  12  Amount            11238 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True)     #axis 0 is row,                                                            axis 1 is col

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11252 entries, 0 to 11251
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11252 non-null  int64
#  1   Cust_name         11252 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  float64
#  6   Marital_Status    11251 non-null  float64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11250 non-null  float64
#  12  Amount            11238 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df).sum()    #isnull()   gives true/false if the data is null
                      #isnull(df).sum()  counts true values(True=1, Flase=0
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           1
# Gender               1
# Age Group            1
# Age                  1
# Marital_Status       1
# State                1
# Zone                 1
# Occupation           1
# Product_Category     1
# Orders               2
# Amount              14
# dtype: int64

# %%
df.dropna(inplace=True)     #it removes the entire row that has NaN

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.shape
# Out:
# (11238, 13)

# %%
df['Amount']=df['Amount'].astype('int')   #convert into differnt datatype

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.rename(columns={'Marital_Status':'marital_status'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group   Age  marital_status  \
# 0      1002903    Sanskriti  P00125942      F     26-35  28.0             0.0
# 1      1000732       Kartik  P00110942      F     26-35  35.0             1.0
# 2      1001990        Bindu  P00118542      F     26-35  35.0             1.0
# 3      1001425       Sudevi  P00237842      M      0-17  16.0             0.0
# 4      1000588         Joni  P00057942      M     26-35  28.0             1.0
# ...        ...          ...        ...    ...       ...   ...             ...
# 11247  1000695      Manning  P00296942      M     18-25  19.0             1.0
# 11248  1004089  Reichenbach  P00171342      M     26-35  33.0             0.0
# 11249  1001209        Oshin  P00201342      F     36-45  40.0             0.0
# 11250  1004023       Noonan  P00059442      M     36-45  37.0             0.0
# 11251  1002744      Brumley  P00281742      F     18-25  19.0             0.0
#
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        User_ID    Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35  28.0             0.0
# 1      1000732       Kartik  P00110942      F     26-35  35.0             1.0
# 2      1001990        Bindu  P00118542      F     26-35  35.0             1.0
# 3      1001425       Sudevi  P00237842      M      0-17  16.0             0.0
# 4      1000588         Joni  P00057942      M     26-35  28.0             1.0
# ...        ...          ...        ...    ...       ...   ...             ...
# 11247  1000695      Manning  P00296942      M     18-25  19.0             1.0
# 11248  1004089  Reichenbach  P00171342      M     26-35  33.0             0.0
# 11249  1001209        Oshin  P00201342      F     36-45  40.0             0.0
# 11250  1004023       Noonan  P00059442      M     36-45  37.0             0.0
# 11251  1002744      Brumley  P00281742      F     18-25  19.0             0.0
#
# ...

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Gender', y='Amount', data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# from the above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men.

# %%
ax=sns.countplot(data=df, x='Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age=df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group', y='Amount', data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %%
sales_state=df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=sales_state, x='State', y='Orders')
#total number of orders from top 10 states
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state=df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=sales_state, x='State', y='Amount')
#total amount/sales from top 10 states
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# From the above graphs we can see that most of the orders and total sales/amount are from uttar pradesh , maharastra, and karnakata.

# %%
    ax=sns.countplot(data=df, x='Marital_Status', hue='Gender')

    sns.set(rc={'figure.figsize':(7,5)})
    for bars in ax.containers:
        ax.bar_label(bars)

# %%
sales_state=df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(7,5)})
sns.barplot(data=sales_state, x='Marital_Status', y='Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see most most of the buyers are married(women) and they have high purchasing power.

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.countplot(data=df, x='Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state=df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state, x='Occupation', y='Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From the above graph we can see that most of the buyers are working in IT, Healthcare and Aviation Sector

# %%
sns.set(rc={'figure.figsize':(30,5)})
ax=sns.countplot(data=df, x='Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state=df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state, x='Product_Category', y='Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From the above graphs we can see that most of the sold products are from food, clothing & Apparel, Electronics & Gadgets and Footware & Shoes

# %%
sales_state=df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state, x='Product_ID', y='Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
fig1,ax1=plt.subplots(figsize=(20,5))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# The above graphs shows the top 10 most sold products

# %% [markdown]
# CONCLUSION:
#
# Married women age group 26-35 yrs from UP, Maharastra and karnataka working in IT, Healthcare, and Aviation are more likely to buy products from food, clothing & Apparel, Electronics & Gadgets and Footware & Shoes Category
